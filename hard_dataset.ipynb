       'dom_vel', 'rain_7days', 'dem', 'slope', 'curvature', 'aspect',
       'ndvi_new', 'evi', 'lst_day', 'lst_night', 'max_dew_temp',
       'mean_dew_temp', 'min_dew_temp', 'fire', 'dir_max_1', 'dir_max_2',
       'dir_max_3', 'dir_max_4', 'dir_max_5', 'dir_max_6', 'dir_max_7',
       'dir_max_8', 'dom_dir_1', 'dom_dir_2', 'dom_dir_3', 'dom_dir_4',
       'dom_dir_5', 'dom_dir_6', 'dom_dir_7', 'dom_dir_8', 'corine_111',
       'corine_112', 'corine_121', 'corine_122', 'corine_123', 'corine_124',
       'corine_131', 'corine_132', 'corine_133', 'corine_141', 'corine_142',
       'corine_211', 'corine_212', 'corine_213', 'corine_221', 'corine_222',
       'corine_223', 'corine_231', 'corine_241', 'corine_242', 'corine_243',
       'corine_244', 'corine_311', 'corine_312', 'corine_313', 'corine_321',
       'corine_322', 'corine_323', 'corine_324', 'corine_331', 'corine_332',
       'corine_333', 'corine_334', 'corine_411', 'corine_412', 'corine_421',
       'corine_422', 'corine_511', 'corine_512', 'corine_521']]
    n = fires.max_temp.count()
    print(n,' fires found')
    nofires = df[df.fire == 0][['max_temp', 'min_temp', 'mean_temp', 'res_max',
       'dom_vel', 'rain_7days', 'dem', 'slope', 'curvature', 'aspect',
       'ndvi_new', 'evi', 'lst_day', 'lst_night', 'max_dew_temp',
       'mean_dew_temp', 'min_dew_temp', 'fire', 'dir_max_1', 'dir_max_2',
       'dir_max_3', 'dir_max_4', 'dir_max_5', 'dir_max_6', 'dir_max_7',
       'dir_max_8', 'dom_dir_1', 'dom_dir_2', 'dom_dir_3', 'dom_dir_4',
       'dom_dir_5', 'dom_dir_6', 'dom_dir_7', 'dom_dir_8', 'corine_111',
       'corine_112', 'corine_121', 'corine_122', 'corine_123', 'corine_124',
       'corine_131', 'corine_132', 'corine_133', 'corine_141', 'corine_142',
       'corine_211', 'corine_212', 'corine_213', 'corine_221', 'corine_222',
       'corine_223', 'corine_231', 'corine_241', 'corine_242', 'corine_243',
       'corine_244', 'corine_311', 'corine_312', 'corine_313', 'corine_321',
       'corine_322', 'corine_323', 'corine_324', 'corine_331', 'corine_332',
       'corine_333', 'corine_334', 'corine_411', 'corine_412', 'corine_421',
       'corine_422', 'corine_511', 'corine_512', 'corine_521']]
    if n == 0:
        return 0,0
    else:
        similarity = sklearn.metrics.pairwise.cosine_similarity(fires, Y=nofires, dense_output=True)
        return n,similarity

# %%
def find_n_similar(n,similarity):
    my_list = []
    for i in range (1,n+1):
        print(i,'/',n)
        k,l = unravel_index(similarity.argmax(), similarity.shape)
        print(similarity[k,l])
        print(l)
        my_list.append(l)
        similarity[k,l] = 0
        print(similarity[k,l])
    return my_list

# %%
dict = {}
for folder, subfolders, files in os.walk('/work2/pa21/sgirtsou/production', topdown=True):
    for file in files:
        if file.endswith('dummies.csv'):
            if file.split('_')[1] in dict:
                dict[file.split('_')[1]].append(os.path.join(os.path.abspath(folder), file))
            else:
                dict[file.split('_')[1]]=[]
                dict[file.split('_')[1]].append(os.path.join(os.path.abspath(folder), file))

# %%
dict

# %%
for key in sorted(dict.keys()):
    print('Year:'+key)
    for i, filename in enumerate(dict[key]):
        df = pd.read_csv(filename)
        print(filename.split('/')[-1])
        n, similarity = cosine_similarity(df)
        tran = np.transpose(similarity)
        tran_df = pd.DataFrame(data = tran,index=df[df.fire==0]['id'],columns=df[df.fire==0]['id'])
        tran_df.to_csv('/'+os.path.join(*filename.split('/')[:-1]+'/similarities.csv)
        if n == 0:
            continue
        else:
            my_list = find_n_similar(n,similarity)
            if i == 0:
                dataset = df[df.fire==1]
                dataset = dataset.append(df.loc[my_list], ignore_index=True)
            else:
                dataset = dataset.append(df[df.fire==1],ignore_index=True)
                dataset = dataset.append(df.loc[my_list], ignore_index=True)
    dataset.to_csv('/work2/pa21/sgirtsou/production/datasets/hard_cosine_similarity/balanced_'+key+'.csv')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-95faa30ac5cd> in <module>()
# ----> 1 df.dtypes
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv('/work2/pa21/sgirtsou/production/2010/09/september_2010_dummies.csv',nrows=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ca4a40674bcf> in <module>()
# ----> 1 df = pd.read_csv('/work2/pa21/sgirtsou/production/2010/09/september_2010_dummies.csv',nrows=10)
#
# NameError: name 'pd' is not defined

# %%
df[(df.id==3286001) & (df.firedate == 20100903)][['id','fire']]

# %%
df[df.fire==1]

# %%
fire_data = pd.read_csv('/users/pa21/sgirtsou/transfered_files/data/fires_10_19.csv')

# %%
fire_data['year'] = fire_data.firedate_g.apply(lambda x: str(x)[0:4])
fire_data['month'] = fire_data.firedate_g.apply(lambda x: str(x)[4:6])

# %%
fire_gouped = fire_data.groupby(['year','month'])['id'].nunique()

# %%
fire_data
# Out:
#        Unnamed: 0         id  firedate_g    firedate  year month
# 0               0  2832256.0  20150723.0         NaN  2015    07
# 1               1  2836710.0  20150723.0         NaN  2015    07
# 2               2  2836711.0  20150723.0         NaN  2015    07
# 3               3  2830029.0  20150723.0         NaN  2015    07
# 4               4  2834480.0  20150723.0         NaN  2015    07
# 5               5  2834481.0  20150723.0         NaN  2015    07
# 6               6  2834482.0  20150723.0         NaN  2015    07
# 7               7  2836709.0  20150723.0         NaN  2015    07
# 8               8  2838937.0  20150723.0         NaN  2015    07
# 9               9  2825572.0  20150723.0         NaN  2015    07
# 10             10  2836708.0  20150723.0         NaN  2015    07
# 11             11  2832255.0  20150723.0         NaN  2015    07
# 12             12  2825571.0  20150723.0         NaN  2015    07
# 13             13  2827798.0  20150723.0         NaN  2015    07
# 14             14  2827799.0  20150723.0         NaN  2015    07
# 15             15  2827800.0  20150723.0         NaN  2015    07
# 16             16  2827801.0  20150723.0         NaN  2015    07
# 17             17  2830025.0  20150723.0         NaN  2015    07
# 18             18  2830026.0  20150723.0         NaN  2015    07
# 19             19  2830027.0  20150723.0         NaN  2015    07
# 20             20  2830028.0  20150723.0         NaN  2015    07
# 21             21  2832253.0  20150723.0         NaN  2015    07
# 22             22  2832254.0  20150723.0         NaN  2015    07
# 23             23  2834483.0  20150723.0         NaN  2015    07
# 24             24  2834484.0  20150723.0         NaN  2015    07
# 25             25  2838936.0  20150723.0         NaN  2015    07
# 26             26  1912160.0  20150721.0         NaN  2015    07
# 27             27  2150617.0  20160708.0         NaN  2016    07
# 28             28  2148389.0  20160708.0         NaN  2016    07
# 29             29  2159528.0  20160708.0         NaN  2016    07
# ...           ...        ...         ...         ...   ...   ...
# 13835         626  1825013.0         NaN  2019-07-05   nan
# 13836         627  1827237.0         NaN  2019-07-05   nan
# 13837         628  1827240.0         NaN  2019-07-05   nan
# 13838         629  1827239.0         NaN  2019-07-05   nan
# 13839         630  1836143.0         NaN  2019-07-05   nan
# 13840         631  1833922.0         NaN  2019-07-05   nan
# 13841         632  1836144.0         NaN  2019-07-05   nan
# 13842         633  1833919.0         NaN  2019-07-05   nan
# 13843         634  1833917.0         NaN  2019-07-05   nan
# 13844         635  1833918.0         NaN  2019-07-05   nan
# 13845         636  1833920.0         NaN  2019-07-05   nan
# 13846         637  1838370.0         NaN  2019-07-05   nan
# 13847         638  1838371.0         NaN  2019-07-05   nan
# 13848         639  1836145.0         NaN  2019-07-05   nan
# 13849         640  1893465.0         NaN  2019-09-12   nan
# 13850         641  1891238.0         NaN  2019-09-12   nan
# 13851         642  1833921.0         NaN  2019-07-05   nan
# 13852         643  1836146.0         NaN  2019-07-05   nan
# 13853         644  1836147.0         NaN  2019-07-05   nan
# 13854         645  1891239.0         NaN  2019-09-12   nan
# 13855         646  1893466.0         NaN  2019-09-12   nan
# 13856         647  1838373.0         NaN  2019-07-05   nan
# 13857         648  1838374.0         NaN  2019-07-05   nan
# 13858         649  1851392.0         NaN  2019-09-01   nan
# 13859         650  1851393.0         NaN  2019-09-01   nan
# 13860         651  1853620.0         NaN  2019-09-01   nan
# 13861         652  1872102.0         NaN  2019-09-13   nan
# 13862         653  1869874.0         NaN  2019-09-13   nan
# 13863         654  1872101.0         NaN  2019-09-13   nan
# 13864         655  1869875.0         NaN  2019-09-13   nan
#
# [13865 rows x 6 columns]

# %%
fire_data[(fire_data.year == '2010')&(fire_data.month == '09')][['id','firedate_g']]

# %% [markdown]
# # Attribute fire row again:

# %%
dict = {'2015': ['/work2/pa21/sgirtsou/production/2015/09/september_2015_dummies.csv',
  '/work2/pa21/sgirtsou/production/2015/04/april_2015_dummies.csv',
  '/work2/pa21/sgirtsou/production/2015/07/july_2015_dummies.csv',
  '/work2/pa21/sgirtsou/production/2015/06/june_2015_dummies.csv'],
 '2016': ['/work2/pa21/sgirtsou/production/2016/05/may_2016_dummies.csv',
  '/work2/pa21/sgirtsou/production/2016/08/august_2016_dummies.csv',
  '/work2/pa21/sgirtsou/production/2016/09/september_2016_dummies.csv',
  '/work2/pa21/sgirtsou/production/2016/04/april_2016_dummies.csv',
  '/work2/pa21/sgirtsou/production/2016/07/july_2016_dummies.csv',
  '/work2/pa21/sgirtsou/production/2016/06/june_2016_dummies.csv'],
 '2017': ['/work2/pa21/sgirtsou/production/2017/05/may_2017_dummies.csv',
  '/work2/pa21/sgirtsou/production/2017/08/august_2017_dummies.csv',
  '/work2/pa21/sgirtsou/production/2017/09/september_2017_dummies.csv',
  '/work2/pa21/sgirtsou/production/2017/04/april_2017_dummies.csv',
  '/work2/pa21/sgirtsou/production/2017/07/july_2017_dummies.csv',
  '/work2/pa21/sgirtsou/production/2017/06/june_2017_dummies.csv'],
 '2018': ['/work2/pa21/sgirtsou/production/2018/05/may_2018_dummies.csv',
  '/work2/pa21/sgirtsou/production/2018/08/august_2018_dummies.csv',
  '/work2/pa21/sgirtsou/production/2018/09/september_2018_dummies.csv',
  '/work2/pa21/sgirtsou/production/2018/04/april_2018_dummies.csv',
  '/work2/pa21/sgirtsou/production/2018/07/july_2018_dummies.csv',
  '/work2/pa21/sgirtsou/production/2018/06/june_2018_dummies.csv']}

# %%
for key in sorted(dict.keys()):
    print('Year:'+key)
    for i, filename in enumerate(dict[key]):
        print(i,filename)
        df = pd.read_csv(filename)
        print(df[df.fire==1]['id'].count())
        for index,row in fire_data[fire_data.year == str(key)].iterrows():
            df.loc[(df.id == row.id) & (df.firedate == row.firedate_g), 'fire'] = 1
        df = df.fillna(0)
        print(df[df.fire == 1]['id'].count())
        df.to_csv(filename)
# Out:
# Year:2013
# 0 /work2/pa21/sgirtsou/production/2013/04/april_2013_dummies.csv
# 31
# 31
# 1 /work2/pa21/sgirtsou/production/2013/07/july_2013_dummies.csv
# 438
# 438
# 2 /work2/pa21/sgirtsou/production/2013/06/june_2013_dummies.csv
# 101
# 101
# Year:2014
# 0 /work2/pa21/sgirtsou/production/2014/05/may_2014_dummies.csv
# 12
# 12
# 1 /work2/pa21/sgirtsou/production/2014/08/august_2014_dummies.csv
# 304
# 304
# 2 /work2/pa21/sgirtsou/production/2014/09/september_2014_dummies.csv
# 26
# 26
# 3 /work2/pa21/sgirtsou/production/2014/04/april_2014_dummies.csv
# 0
# 0
# 4 /work2/pa21/sgirtsou/production/2014/07/july_2014_dummies.csv
# 311
# 311
# 5 /work2/pa21/sgirtsou/production/2014/06/june_2014_dummies.csv
# 257
# 257
# Year:2015
# 0 /work2/pa21/sgirtsou/production/2015/05/may_2015_dummies.csv
# 7
# 7
# 1 /work2/pa21/sgirtsou/production/2015/08/august_2015_dummies.csv
# 144
# 144
# 2 /work2/pa21/sgirtsou/production/2015/09/september_2015_dummies.csv
# 206
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-fb9f1477388f> in <module>()
#       6         print(df[df.fire==1]['id'].count())
#       7         for index,row in fire_data[fire_data.year == str(key)].iterrows():
# ----> 8             df.loc[(df.id == row.id) & (df.firedate == row.firedate_g), 'fire'] = 1
#       9         df = df.fillna(0)
#      10         print(df[df.fire == 1]['id'].count())
#
# /apps/applications/python/anaconda3/5.0.1/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     176         else:
#     177             key = com._apply_if_callable(key, self.obj)
# --> 178         indexer = self._get_setitem_indexer(key)
#     179         self._setitem_with_indexer(indexer, value)
#     180
#
# /apps/applications/python/anaconda3/5.0.1/lib/python3.6/site-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     155         if isinstance(key, tuple):
#     156             try:
# --> 157                 return self._convert_tuple(key, is_setter=True)
#     158             except IndexingError:
#     159                 pass
#
# /apps/applications/python/anaconda3/5.0.1/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_tuple(self, key, is_setter)
#     222                 if i >= self.obj.ndim:
#     223                     raise IndexingError('Too many indexers')
# --> 224                 idx = self._convert_to_indexer(k, axis=i, is_setter=is_setter)
#     225                 keyidx.append(idx)
#     226         return tuple(keyidx)
#
# /apps/applications/python/anaconda3/5.0.1/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1204             if is_bool_indexer(obj):
#    1205                 obj = check_bool_indexer(labels, obj)
# -> 1206                 inds, = obj.nonzero()
#    1207                 return inds
#    1208             else:
#
# KeyboardInterrupt:

# %%
for index,row in fire_data.iterrows():
    df.loc[(df.id == row.id) & (df.firedate == row.firedate_g), 'fire'] = 1

# %%
df[df['id'].isin(list(fire_data[(fire_data.year == '2010') & (fire_data.month == '09')]['id']))]

# %%
list(fire_data[(fire_data.year == '2010') & (fire_data.month == '09')]['id'])

# %%
for key in (dict.keys()):
    print('Year:'+key)

# %%
df[df.fire == 1]['id'].count()

# %%
dataset = dataset.append(df.loc[in_list], ignore_index=True)

# %%
dataset

# %%
for index,row in fires.iterrows():
    df.loc[(df.id == row.id) & (df.firedate == row.firedate_g), 'fire'] = 1

# %%
fire_data[fire_data.firedate_g<20110000.0]

# %%
fire_data.dtypes

# %% [markdown]
# # Min max values

# %%
fields = ['max_temp', 'min_temp', 'mean_temp', 'res_max',
       'dom_vel', 'rain_7days', 'dem', 'slope', 'curvature', 'aspect',
       'ndvi_new', 'evi', 'lst_day', 'lst_night', 'max_dew_temp',
       'mean_dew_temp', 'min_dew_temp']

# %%
d = {'aspect': {'max': [], 'min': []},
'curvature': {'max': [], 'min': []},
'dem': {'max': [], 'min': []},
'dom_vel': {'max': [], 'min': []},
'evi': {'max': [], 'min': []},
'lst_day': {'max': [], 'min': []},
'lst_night': {'max': [], 'min': []},
'max_dew_temp': {'max': [], 'min': []},
'max_temp': {'max': [], 'min': []},
'mean_dew_temp': {'max': [], 'min': []},
'mean_temp': {'max': [], 'min': []},
'min_dew_temp': {'max': [], 'min': []},
'min_temp': {'max': [], 'min': []},
'ndvi_new': {'max': [], 'min': []},
'rain_7days': {'max': [], 'min': []},
'res_max': {'max': [], 'min': []},
'slope': {'max': [], 'min': []}}

# %%
for key in sorted(dict.keys()):
    print('Year:'+key)
    for i, filename in enumerate(dict[key]):
        df = pd.read_csv(filename, usecols=fields)
        for f in fields:
            d[f]['max'].append(df[f].max())
            d[f]['min'].append(df[f].min())

# %%
for key in sorted(d.keys()):

# %%
min_max_dic = {'aspect': {'max': [], 'min': []},
'curvature': {'max': [], 'min': []},
'dem': {'max': [], 'min': []},
'dom_vel': {'max': [], 'min': []},
'evi': {'max': [], 'min': []},
'lst_day': {'max': [], 'min': []},
'lst_night': {'max': [], 'min': []},
'max_dew_temp': {'max': [], 'min': []},
'max_temp': {'max': [], 'min': []},
'mean_dew_temp': {'max': [], 'min': []},
'mean_temp': {'max': [], 'min': []},
'min_dew_temp': {'max': [], 'min': []},
'min_temp': {'max': [], 'min': []},
'ndvi_new': {'max': [], 'min': []},
'rain_7days': {'max': [], 'min': []},
'res_max': {'max': [], 'min': []},
'slope': {'max': [], 'min': []}}

# %%
for key in sorted(d.keys()):
    print(key)
    print(max(d[key]['max']))
    print(min(d[key]['min']))

# %%
for key in sorted(d.keys()):
    min_max_dic[key]['max'] = max(d[key]['max'])
    min_max_dic[key]['min'] = min(d[key]['min'])
#    print(key)
#    print(max(d[key]['max']))
#    print(min(d[key]['min']))

# %%
min_max_dic

# %% [markdown]
# # Insert month, weekday, historical frequency and apply normalization

# %%
d = {'aspect': {'max': 359.99800000000016, 'min': -1.0},
 'curvature': {'max': 0.73661599999999994, 'min': -0.76867799999999997},
 'dem': {'max': 2806.1399999999999, 'min': -6.04},
 'dom_vel': {'max': 19.337629295696285, 'min': 0.49528943306704032},
 'evi': {'max': 0.99250000000000005, 'min': -0.19869999999999999},
 'lst_day': {'max': 342.77999999999997, 'min': 251.78},
 'lst_night': {'max': 322.45999999999998, 'min': 254.47999572753903},
 'max_dew_temp': {'max': 300.5537109375, 'min': 266.383056640625},
 'max_temp': {'max': 317.44775390625, 'min': 273.447509765625},
 'mean_dew_temp': {'max': 298.55347696940106, 'min': 263.98918660481769},
 'mean_temp': {'max': 309.74698893229169, 'min': 270.31141153971362},
 'min_dew_temp': {'max': 297.611083984375, 'min': 258.5595703125},
 'min_temp': {'max': 303.00634765625, 'min': 262.879150390625},
 'ndvi_new': {'max': 0.99939999999999996, 'min': -0.20000000000000001},
 'rain_7days': {'max': 3.5451469016037436, 'min': 6.8902961061212417e-06},
 'res_max': {'max': 19.337629295696285, 'min': 2.7861490154313331},
 'slope': {'max': 45.0045, 'min': 0.0}}

# %%
def normalized_values(y,dfmax, dfmin):
    a = (y- dfmin) / (dfmax - dfmin)
    return(a)

# %%
df = pd.read_csv('/work2/pa21/sgirtsou/production/2010/08/august_2010_dummies.csv',nrows=100)

# %%
df.columns
df['wkd'] = pd.to_datetime(df['firedate'],format='%Y%m%d').dt.dayofweek
df['month'] = pd.to_datetime(df['firedate'],format='%Y%m%d').dt.month

# %%
df1 = pd.get_dummies(df, columns=['wkd', 'month'])

# %%
months = ['month_4','month_5','month_6','month_7','month_8','month_9']

# %%
for m in months:
    if m not in df1.columns:
        print(m)
        df1[m] = 0

# %%
df1.loc[0]

# %%
for key in d:
    print(key)
    df1[key] = df1[key].apply(lambda x: normalized_values(x,d[key]['max'], d[key]['min']))

# %%
dict['2010'][0][:-12]

# %%
for key in sorted(dict.keys()):
    print('Year:'+key)
    for i, filename in enumerate(dict[key]):
        print('Reading '+filename)
        df = pd.read_csv(filename)
        if df[df.fire == 1]['id'].count()>0:
            df['month'] = pd.to_datetime(df['firedate'],format='%Y%m%d').dt.month
            df['wkd'] = pd.to_datetime(df['firedate'],format='%Y%m%d').dt.dayofweek
            df1 = pd.get_dummies(df, columns=['wkd', 'month'])
            del df
            for m in months:
                if m not in df1.columns:
                    print(m+ 'was not in columns of' + filename)
                    df1[m] = 0    
            #print(df1.columns)
            for key in d:
                print(key)
                df1[key] = df1[key].apply(lambda x: normalized_values(x,d[key]['max'], d[key]['min']))
                df1.to_csv(filename[:-12]+'_norm.csv')
        else:
            print("No fire found in "+ filename)

# %%
df10 = pd.read_csv('')
